# %%
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
from matplotlib import style

# %%
# %matplotlib inline

# %%
df = pd.read_csv('allstates.csv', usecols=[0,1,15,24,25,37,51])
#print(df)

# %%
style.use('seaborn-whitegrid')
#Some different styles.
#fivethirtyeight
#seaborn-pastel
#ggplot
#grayscale

# %%
df.plot(x='Year');
